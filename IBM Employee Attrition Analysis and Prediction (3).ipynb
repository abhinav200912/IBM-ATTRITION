# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#import plotly as px
# %matplotlib inline
pd.options.mode.chained_assignment = None  # default = 'warn'
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
Train=pd.read_csv("trainibm.csv")
Train.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
Train.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
Train.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1058.000000  1058.000000  1058.000000       1058.000000  1058.000000
# mean     37.055766     0.169187   809.542533          8.978261     2.879017
# std       9.410421     0.375094   408.478049          8.040608     1.031442
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.250000          2.000000     2.000000
# 50%      36.000000     0.000000   817.500000          7.000000     3.000000
# 75%      43.000000     0.000000  1168.500000         13.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1058.0     1058.000000              1058.000000  1058.000000
# mean             1.0      731.753308                 2.712665    65.643667
# ...

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1058 entries, 0 to 1057
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1058 non-null   int64
#  1   Attrition                 1058 non-null   int64
#  2   BusinessTravel            1058 non-null   object
#  3   DailyRate                 1058 non-null   int64
#  4   Department                1058 non-null   object
#  5   DistanceFromHome          1058 non-null   int64
#  6   Education                 1058 non-null   int64
#  7   EducationField            1058 non-null   object
#  8   EmployeeCount             1058 non-null   int64
#  9   EmployeeNumber            1058 non-null   int64
#  10  EnvironmentSatisfaction   1058 non-null   int64
#  11  Gender                    1058 non-null   object
#  12  HourlyRate                1058 non-null   int64
#  13  JobInvolvement            1058 non-null   int64
# ...

# %%
Train.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
Train.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    731
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1058
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome                991
# MonthlyRate                 1038
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
Test=pd.read_csv("testibm.csv")
Test.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   34      Travel_Rarely        790                   Sales
# 1   35      Travel_Rarely        660                   Sales
# 2   24  Travel_Frequently        381  Research & Development
# 3   24         Non-Travel        830                   Sales
# 4   44  Travel_Frequently       1193  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                24          4        Medical              1            1489
# 1                 7          1  Life Sciences              1            1492
# 2                 9          3        Medical              1            1494
# 3                13          2  Life Sciences              1            1495
# 4                 2          1        Medical              1            1496
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# ...

# %%
Test.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
Test.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  412.000000   412.000000        412.000000  412.000000          412.0
# mean    36.584951   784.364078          9.742718    3.000000            1.0
# std      8.389257   390.361319          8.258996    1.001216            0.0
# min     18.000000   104.000000          1.000000    1.000000            1.0
# 25%     31.000000   464.750000          2.000000    2.000000            1.0
# 50%     35.500000   740.500000          8.000000    3.000000            1.0
# 75%     42.000000  1147.750000         15.000000    4.000000            1.0
# max     60.000000  1495.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      412.000000               412.000000  412.000000      412.000000
# mean      1777.565534                 2.745146   66.526699        2.711165
# ...

# %%
Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       412 non-null    int64
#  1   BusinessTravel            412 non-null    object
#  2   DailyRate                 412 non-null    int64
#  3   Department                412 non-null    object
#  4   DistanceFromHome          412 non-null    int64
#  5   Education                 412 non-null    int64
#  6   EducationField            412 non-null    object
#  7   EmployeeCount             412 non-null    int64
#  8   EmployeeNumber            412 non-null    int64
#  9   EnvironmentSatisfaction   412 non-null    int64
#  10  Gender                    412 non-null    object
#  11  HourlyRate                412 non-null    int64
#  12  JobInvolvement            412 non-null    int64
#  13  JobLevel                  412 non-null    int64
# ...

# %%
Test.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
Test.nunique()
# Out:
# Age                          40
# BusinessTravel                3
# DailyRate                   354
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# EmployeeNumber              412
# EnvironmentSatisfaction       4
# Gender                        2
# HourlyRate                   71
# JobInvolvement                4
# JobLevel                      5
# JobRole                       9
# JobSatisfaction               4
# MaritalStatus                 3
# MonthlyIncome               406
# MonthlyRate                 410
# NumCompaniesWorked           10
# Over18                        1
# OverTime                      2
# PercentSalaryHike            15
# PerformanceRating             2
# RelationshipSatisfaction      4
# StandardHours                 1
# StockOptionLevel              4
# TotalWorkingYears            36
# TrainingTimesLastYear         7
# ...

# %% [markdown]
# # BASIC PREPROCESSING

# %% [markdown]
# ## TRAIN SET

# %%
Train
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1053   57          0      Travel_Rarely        405  Research & Development
# 1054   49          0      Travel_Rarely       1490  Research & Development
# 1055   34          0  Travel_Frequently        829  Research & Development
# 1056   28          1  Travel_Frequently       1496                   Sales
# 1057   29          1  Travel_Frequently        115                   Sales
#
# ...

# %% [markdown]
# ### removing constant columns by checking the unique values present in the train set

# %%
Train.drop(columns=['EmployeeCount','Over18','StandardHours'], axis=1, inplace=True)
Train
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1053   57          0      Travel_Rarely        405  Research & Development
# 1054   49          0      Travel_Rarely       1490  Research & Development
# 1055   34          0  Travel_Frequently        829  Research & Development
# 1056   28          1  Travel_Frequently       1496                   Sales
# 1057   29          1  Travel_Frequently        115                   Sales
#
# ...

# %% [markdown]
# ### 3 columnns were deleted i.e.
#             *EmployeeCount
#             *Over18
#             *StandardHours

# %%
Train.shape
# Out:
# (1058, 32)

# %% [markdown]
# ### while deleting quasi constant columns, no evident changes were seen.

# %%
Train.drop(labels=list(filter(lambda keys: Train[keys].value_counts().max()> 0.99*Train.shape[0],Train.keys())),axis=1,inplace=True)
Train.shape
# Out:
# (1058, 32)

# %% [markdown]
# ### Finding and removing duplicates,but there are no duplicates

# %%
Train_t = Train.T
Train_t.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## TEST SET

# %%
Test
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 0     34      Travel_Rarely        790                   Sales
# 1     35      Travel_Rarely        660                   Sales
# 2     24  Travel_Frequently        381  Research & Development
# 3     24         Non-Travel        830                   Sales
# 4     44  Travel_Frequently       1193  Research & Development
# ..   ...                ...        ...                     ...
# 407   36  Travel_Frequently        884  Research & Development
# 408   39      Travel_Rarely        613  Research & Development
# 409   27      Travel_Rarely        155  Research & Development
# 410   49  Travel_Frequently       1023                   Sales
# 411   34      Travel_Rarely        628  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                  24          4        Medical              1
# 1                   7          1  Life Sciences              1
# ...

# %% [markdown]
# ### removing constant columns by checking the unique values present in the train set

# %%
Test.drop(columns=['EmployeeCount','Over18','StandardHours'], axis=1, inplace=True)
Test
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 0     34      Travel_Rarely        790                   Sales
# 1     35      Travel_Rarely        660                   Sales
# 2     24  Travel_Frequently        381  Research & Development
# 3     24         Non-Travel        830                   Sales
# 4     44  Travel_Frequently       1193  Research & Development
# ..   ...                ...        ...                     ...
# 407   36  Travel_Frequently        884  Research & Development
# 408   39      Travel_Rarely        613  Research & Development
# 409   27      Travel_Rarely        155  Research & Development
# 410   49  Travel_Frequently       1023                   Sales
# 411   34      Travel_Rarely        628  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                  24          4        Medical            1489
# 1                   7          1  Life Sciences            1492
# ...

# %% [markdown]
# ### 3 columnns were deleted i.e.
#         *EmployeeCount
#         *Over18
#         *StandardHours

# %% [markdown]
# ### while deleting quasi constant columns, no evident changes were seen.

# %%
Test.drop(labels=list(filter(lambda keys: Test[keys].value_counts().max()> 0.99*Test.shape[0],Test.keys())),axis=1,inplace=True)
Test.shape
# Out:
# (412, 31)

# %% [markdown]
# ### Finding and removing duplicates,but there are no duplicate

# %%
Test_t = Test.T
Test_t.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Explanatory Data Analysis(EDA) on TRAIN Set

# %%
sns.set_style('whitegrid')
sns.distplot(Train['Age'],kde=True,bins=20,color='red')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
cat=Train.select_dtypes(include=["object"])
for feat in cat.columns:
    sns.catplot(data = Train, kind = 'count', aspect = 9, height = 2, x = feat,palette='Set3')

# %%
corr=Train.corr()
plt.figure(figsize=(25,20))
sns.heatmap(corr,annot=True,cmap="afmhot_r")
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(5,2, figsize=(14,14))
sns.distplot(Train['TotalWorkingYears'], ax = ax[0,0],color='maroon')
sns.distplot(Train['MonthlyIncome'], ax = ax[0,1],color='maroon')
sns.distplot(Train['YearsAtCompany'], ax = ax[1,0],color='maroon')
sns.distplot(Train['DistanceFromHome'], ax = ax[1,1],color='maroon')
sns.distplot(Train['YearsWithCurrManager'], ax = ax[2,0],color='maroon')
sns.distplot(Train['YearsSinceLastPromotion'], ax = ax[2,1],color='maroon')
sns.distplot(Train['PercentSalaryHike'], ax = ax[3,0],color='maroon')
sns.distplot(Train['YearsAtCompany'], ax = ax[3,1],color='maroon')
sns.distplot(Train['YearsSinceLastPromotion'], ax = ax[4,0],color='maroon')
sns.distplot(Train['TrainingTimesLastYear'], ax = ax[4,1],color='maroon')
plt.tight_layout()
plt.show()

# %%
continious = ['Age',  'DailyRate', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'TotalWorkingYears', 'YearsAtCompany' ]

for var in continious:
    #boxplot
    plt.figure(figsize = (15,5))
    plt.subplot(1,2,1)
    fig = Train.boxplot(column = var)
    fig.set_ylabel(var)
    
    #histogram
    plt.subplot(1,2,2)
    fig = Train[var].hist(bins = 20,color='skyblue')
    fig.set_ylabel('No. of Employees')
    fig.set_xlabel(var)
    
    plt.show()

# %%
labels = ['Research & Development','Sales','Human Resources']
# sizes = [15, 30, 45, 10]#colors
colors = ['#ff9999','#66b3ff','#99ff99']
 
fig1, ax1 = plt.subplots()
ax1.pie(Train['Department'].value_counts(), colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
labels = ['Life Sciences','Medical','Marketing','Technical Degree','Other','Human Resources']
colors = ['#ff9999','#66b3ff','#99ff99','#fff033','#b671ff','#daff71']
 
fig1, ax1 = plt.subplots()
ax1.pie(Train['EducationField'].value_counts(), colors = colors, labels=labels, autopct='%1.1f%%', startangle=90)#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
sns.jointplot(x='Age',y='DailyRate',data=Train,kind='kde')

# %% [markdown]
# # Feature Engineering

# %%
num=Train.select_dtypes(exclude=["object"])
num.columns
# Out:
# Index(['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### Target Encoding

# %%
categorical_cols = {'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole','MaritalStatus', 'OverTime'}
for col in categorical_cols:
    target_mapper = Train.groupby(col)['Attrition'].mean().to_dict()
    Train[col] =  Train[col].map(target_mapper)
    Test[col] =  Test[col].map(target_mapper)

# %%
Train
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1        0.156836       1102    0.206897                 1
# 1      49          0        0.248780        279    0.152639                 8
# 2      37          1        0.156836       1373    0.152639                 2
# 3      33          0        0.248780       1392    0.152639                 3
# 4      27          0        0.156836        591    0.152639                 2
# ...   ...        ...             ...        ...         ...               ...
# 1053   57          0        0.156836        405    0.152639                 1
# 1054   49          0        0.156836       1490    0.152639                 7
# 1055   34          0        0.248780        829    0.152639                15
# 1056   28          1        0.248780       1496    0.206897                 1
# 1057   29          1        0.248780        115    0.206897                13
#
# ...

# %%
Test
# Out:
#      Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0     34        0.156836        790    0.206897                24          4
# 1     35        0.156836        660    0.206897                 7          1
# 2     24        0.248780        381    0.152639                 9          3
# 3     24        0.102804        830    0.206897                13          2
# 4     44        0.248780       1193    0.152639                 2          1
# ..   ...             ...        ...         ...               ...        ...
# 407   36        0.248780        884    0.152639                23          2
# 408   39        0.156836        613    0.152639                 6          1
# 409   27        0.156836        155    0.152639                 4          3
# 410   49        0.248780       1023    0.206897                 2          3
# 411   34        0.156836        628    0.152639                 8          3
#
# ...

# %%
x=[['Age', 'DailyRate', 'DistanceFromHome', 'Education',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
       'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
for col in x:
    Train[col] = scaler.fit_transform(Train[col])
    Test[col] = scaler.transform(Test[col])

# %%
Train
# Out:
#            Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     0.547619          1        0.156836   0.715820    0.206897
# 1     0.738095          0        0.248780   0.126700    0.152639
# 2     0.452381          1        0.156836   0.909807    0.152639
# 3     0.357143          0        0.248780   0.923407    0.152639
# 4     0.214286          0        0.156836   0.350036    0.152639
# ...        ...        ...             ...        ...         ...
# 1053  0.928571          0        0.156836   0.216893    0.152639
# 1054  0.738095          0        0.156836   0.993558    0.152639
# 1055  0.380952          0        0.248780   0.520401    0.152639
# 1056  0.238095          1        0.248780   0.997853    0.206897
# 1057  0.261905          1        0.248780   0.009306    0.206897
#
#       DistanceFromHome  Education  EducationField  EmployeeNumber  \
# 0             0.000000       0.25        0.160550        0.000000
# ...

# %%
Test
# Out:
#           Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0    0.380952        0.156836   0.492484    0.206897          0.821429
# 1    0.404762        0.156836   0.399427    0.206897          0.214286
# 2    0.142857        0.248780   0.199714    0.152639          0.285714
# 3    0.142857        0.102804   0.521117    0.206897          0.428571
# 4    0.619048        0.248780   0.780959    0.152639          0.035714
# ..        ...             ...        ...         ...               ...
# 407  0.428571        0.248780   0.559771    0.152639          0.785714
# 408  0.500000        0.156836   0.365784    0.152639          0.178571
# 409  0.214286        0.156836   0.037938    0.152639          0.107143
# 410  0.738095        0.248780   0.659270    0.206897          0.035714
# 411  0.380952        0.156836   0.376521    0.152639          0.250000
#
#      Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# ...

# %%
Train.min()
# Out:
# Age                         0.000000
# Attrition                   0.000000
# BusinessTravel              0.102804
# DailyRate                   0.000000
# Department                  0.152639
# DistanceFromHome            0.000000
# Education                   0.000000
# EducationField              0.133333
# EmployeeNumber              0.000000
# EnvironmentSatisfaction     0.000000
# Gender                      0.162100
# HourlyRate                  0.000000
# JobInvolvement              0.000000
# JobLevel                    0.000000
# JobRole                     0.032258
# JobSatisfaction             0.000000
# MaritalStatus               0.095041
# MonthlyIncome               0.000000
# MonthlyRate                 0.000000
# NumCompaniesWorked          0.000000
# OverTime                    0.107856
# PercentSalaryHike           0.000000
# PerformanceRating           0.000000
# RelationshipSatisfaction    0.000000
# StockOptionLevel            0.000000
# ...

# %%
Test.min()
# Out:
# Age                         0.000000
# BusinessTravel              0.102804
# DailyRate                   0.001432
# Department                  0.152639
# DistanceFromHome            0.000000
# Education                   0.000000
# EducationField              0.133333
# EmployeeNumber              1.001346
# EnvironmentSatisfaction     0.000000
# Gender                      0.162100
# HourlyRate                  0.000000
# JobInvolvement              0.000000
# JobLevel                    0.000000
# JobRole                     0.032258
# JobSatisfaction             0.000000
# MaritalStatus               0.095041
# MonthlyIncome               0.003791
# MonthlyRate                 0.000120
# NumCompaniesWorked          0.000000
# OverTime                    0.107856
# PercentSalaryHike           0.000000
# PerformanceRating           0.000000
# RelationshipSatisfaction    0.000000
# StockOptionLevel            0.000000
# TotalWorkingYears           0.000000
# ...

# %%
#dropping 'EmployeeNumber' from both of train and test sets as all values are unique
Train.drop('EmployeeNumber',inplace=True,axis=1)
Test.drop('EmployeeNumber',inplace=True,axis=1)

# %%
Train
# Out:
#            Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     0.547619          1        0.156836   0.715820    0.206897
# 1     0.738095          0        0.248780   0.126700    0.152639
# 2     0.452381          1        0.156836   0.909807    0.152639
# 3     0.357143          0        0.248780   0.923407    0.152639
# 4     0.214286          0        0.156836   0.350036    0.152639
# ...        ...        ...             ...        ...         ...
# 1053  0.928571          0        0.156836   0.216893    0.152639
# 1054  0.738095          0        0.156836   0.993558    0.152639
# 1055  0.380952          0        0.248780   0.520401    0.152639
# 1056  0.238095          1        0.248780   0.997853    0.206897
# 1057  0.261905          1        0.248780   0.009306    0.206897
#
#       DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0             0.000000       0.25        0.160550                 0.333333
# ...

# %%
Test
# Out:
#           Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0    0.380952        0.156836   0.492484    0.206897          0.821429
# 1    0.404762        0.156836   0.399427    0.206897          0.214286
# 2    0.142857        0.248780   0.199714    0.152639          0.285714
# 3    0.142857        0.102804   0.521117    0.206897          0.428571
# 4    0.619048        0.248780   0.780959    0.152639          0.035714
# ..        ...             ...        ...         ...               ...
# 407  0.428571        0.248780   0.559771    0.152639          0.785714
# 408  0.500000        0.156836   0.365784    0.152639          0.178571
# 409  0.214286        0.156836   0.037938    0.152639          0.107143
# 410  0.738095        0.248780   0.659270    0.206897          0.035714
# 411  0.380952        0.156836   0.376521    0.152639          0.250000
#
#      Education  EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# ...

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Filter Method

# %%
#Correlation heatmap helps in checking inter-correlation between columns

# %%
corrr=Train.corr()
plt.figure(figsize=(25,15))
sns.heatmap(corrr,annot=True)
# Out:
# <AxesSubplot:>

# %%
#helps in finding out unnecessary features
def handling_correlation(df,threshold=0.8):
    # creating set to hold the correlated features
    corr_features = set()
    # create the correlation matrix (default to pearson)
    corr_matrix = df.corr()
    #code for selecting all correleated features
    for i in range(len(corr_matrix .columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) >threshold:
                colname = corr_matrix.columns[i]
                corr_features.add(colname)
    return list(corr_features)
#in the time of checking co-relation we have to check with target also that's why I am passing out output_label also
handling_correlation(Train.copy(),0.85)
# Out:
# ['MonthlyIncome']

# %%
#dropping  features on the basis of filter method
Train.drop('MonthlyIncome',inplace=True,axis=1)
Test.drop('MonthlyIncome',inplace=True,axis=1)

# %%
Train
# Out:
#            Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     0.547619          1        0.156836   0.715820    0.206897
# 1     0.738095          0        0.248780   0.126700    0.152639
# 2     0.452381          1        0.156836   0.909807    0.152639
# 3     0.357143          0        0.248780   0.923407    0.152639
# 4     0.214286          0        0.156836   0.350036    0.152639
# ...        ...        ...             ...        ...         ...
# 1053  0.928571          0        0.156836   0.216893    0.152639
# 1054  0.738095          0        0.156836   0.993558    0.152639
# 1055  0.380952          0        0.248780   0.520401    0.152639
# 1056  0.238095          1        0.248780   0.997853    0.206897
# 1057  0.261905          1        0.248780   0.009306    0.206897
#
#       DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0             0.000000       0.25        0.160550                 0.333333
# ...

# %%
Test
# Out:
#           Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0    0.380952        0.156836   0.492484    0.206897          0.821429
# 1    0.404762        0.156836   0.399427    0.206897          0.214286
# 2    0.142857        0.248780   0.199714    0.152639          0.285714
# 3    0.142857        0.102804   0.521117    0.206897          0.428571
# 4    0.619048        0.248780   0.780959    0.152639          0.035714
# ..        ...             ...        ...         ...               ...
# 407  0.428571        0.248780   0.559771    0.152639          0.785714
# 408  0.500000        0.156836   0.365784    0.152639          0.178571
# 409  0.214286        0.156836   0.037938    0.152639          0.107143
# 410  0.738095        0.248780   0.659270    0.206897          0.035714
# 411  0.380952        0.156836   0.376521    0.152639          0.250000
#
#      Education  EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# ...

# %% [markdown]
# # Modeling On Train Set

# %%
#Splitting Train Data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Train.drop(columns = ['Attrition'],axis=1), Train.Attrition)

# %%
X_train.shape,y_train.shape
# Out:
# ((793, 29), (793,))

# %% [markdown]
# ### 1.Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
model = LogisticRegression()
model.fit(X_train,y_train)
model_predictions = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, model_predictions))
print(classification_report(y_test, model_predictions))
# Out:
# Accuracy:  0.8679245283018868
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       220
#            1       0.92      0.24      0.39        45
#
#     accuracy                           0.87       265
#    macro avg       0.89      0.62      0.66       265
# weighted avg       0.87      0.87      0.83       265

# %% [markdown]
# ### 2.Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,y_train)
model_predictions = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, model_predictions))
print(classification_report(y_test, model_predictions))
# Out:
# Accuracy:  0.8377358490566038
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91       220
#            1       0.60      0.13      0.22        45
#
#     accuracy                           0.84       265
#    macro avg       0.72      0.56      0.56       265
# weighted avg       0.81      0.84      0.79       265

# %% [markdown]
# ### 3.Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
model_predictions = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, model_predictions))
print(classification_report(y_test, model_predictions))
# Out:
# Accuracy:  0.7849056603773585
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       220
#            1       0.37      0.38      0.37        45
#
#     accuracy                           0.78       265
#    macro avg       0.62      0.62      0.62       265
# weighted avg       0.79      0.78      0.79       265

# %% [markdown]
# ### 4.K-Neighbors Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(X_train,y_train)
model_predictions = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, model_predictions))
print(classification_report(y_test, model_predictions))
# Out:
# Accuracy:  0.8452830188679246
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91       220
#            1       0.64      0.20      0.31        45
#
#     accuracy                           0.85       265
#    macro avg       0.75      0.59      0.61       265
# weighted avg       0.82      0.85      0.81       265

# %% [markdown]
# ### 5.Support Vector Classifier

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,y_train)
model_predictions = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, model_predictions))
print(classification_report(y_test, model_predictions))
# Out:
# Accuracy:  0.8415094339622642
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       220
#            1       1.00      0.07      0.12        45
#
#     accuracy                           0.84       265
#    macro avg       0.92      0.53      0.52       265
# weighted avg       0.87      0.84      0.78       265

# %% [markdown]
# ### 6.XGBoost Classifier

# %%
from xgboost.sklearn import XGBClassifier
model = XGBClassifier(use_label_encoder=False)
model.fit(X_train,y_train)
model_predictions = model.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, model_predictions))
print(classification_report(y_test, model_predictions))
# Out:
# [13:59:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy:  0.8528301886792453
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       220
#            1       0.62      0.33      0.43        45
#
#     accuracy                           0.85       265
#    macro avg       0.75      0.65      0.68       265
# weighted avg       0.83      0.85      0.83       265

# %% [markdown]
# ### 7.Keras Classification

# %%
# !pip install tensorflow

# %%
#tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout

#EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping

# %%
#building sequential neural network
model = Sequential()

model.add(Dense(units=100,activation='relu'))
model.add(Dropout(0.5)) 

model.add(Dense(units=50,activation='relu'))
model.add(Dropout(0.5)) 

model.add(Dense(units=25,activation='relu'))
model.add(Dropout(0.5)) 

model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer = 'adam')

# %%
#using early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1, patience=5)

# %%
#fitting model into training datasets
model.fit(x = X_train,
          y = y_train,
          batch_size = 128,
          epochs = 100,
          validation_data = (X_test,y_test),verbose =1,
          callbacks = [early_stop]
          )
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 46ms/step - loss: 0.8505 - val_loss: 0.6663
# Epoch 2/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6753 - val_loss: 0.5963
# Epoch 3/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6299 - val_loss: 0.5513
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.5761 - val_loss: 0.5059
# Epoch 5/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5479 - val_loss: 0.4709
# Epoch 6/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5463 - val_loss: 0.4517
# Epoch 7/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5174 - val_loss: 0.4427
# Epoch 8/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4991 - val_loss: 0.4403
# Epoch 9/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4920 - val_loss: 0.4377
# Epoch 10/100
# ...

# %%
model.history.history
# Out:
# {'loss': [0.8504728078842163,
#   0.675288200378418,
#   0.6299493312835693,
#   0.5760736465454102,
#   0.5479483008384705,
#   0.5463385581970215,
#   0.5174113512039185,
#   0.49905523657798767,
#   0.49201932549476624,
#   0.5075196623802185,
#   0.48791319131851196,
#   0.4776286482810974,
#   0.4876261055469513,
#   0.478367418050766,
#   0.46771571040153503,
#   0.46555396914482117,
#   0.47260594367980957,
#   0.46038028597831726,
#   0.4658108353614807,
#   0.45791491866111755,
#   0.4525280296802521,
#   0.44929060339927673,
#   0.46411529183387756,
#   0.44378697872161865,
#   0.4437866508960724,
#   0.431792676448822,
#   0.43361079692840576,
#   0.43157142400741577,
#   0.4355026185512543,
#   0.4361226260662079,
#   0.4339776337146759,
#   0.43609684705734253,
#   0.4370882213115692,
#   0.41934913396835327,
#   0.42034465074539185,
#   0.421915203332901,
#   0.40887507796287537,
#   0.3946748673915863,
#   0.3874979019165039,
#   0.39286431670188904,
# ...

# %%
#plotting training and validation losses
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import confusion_matrix
#confusion matrix
y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test,y_pred))
# Out:
# [[216   4]
#  [ 28  17]]
# C:\Users\KIIT\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#classification report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93       220
#            1       0.81      0.38      0.52        45
#
#     accuracy                           0.88       265
#    macro avg       0.85      0.68      0.72       265
# weighted avg       0.87      0.88      0.86       265

# %% [markdown]
# # Prediction On Test Set

# %% [markdown]
# ### Logistic Regression has highest accuracy of 90.56% , So I chose Logistic regression

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
model_predictions = model.predict(Test)

# %%
model_predictions = pd.Series(model_predictions)
model_predictions
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 407    0
# 408    0
# 409    0
# 410    0
# 411    0
# Length: 412, dtype: int64

# %%
Test['Attrition'] = model_predictions.values
Test
# Out:
#           Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0    0.380952        0.156836   0.492484    0.206897          0.821429
# 1    0.404762        0.156836   0.399427    0.206897          0.214286
# 2    0.142857        0.248780   0.199714    0.152639          0.285714
# 3    0.142857        0.102804   0.521117    0.206897          0.428571
# 4    0.619048        0.248780   0.780959    0.152639          0.035714
# ..        ...             ...        ...         ...               ...
# 407  0.428571        0.248780   0.559771    0.152639          0.785714
# 408  0.500000        0.156836   0.365784    0.152639          0.178571
# 409  0.214286        0.156836   0.037938    0.152639          0.107143
# 410  0.738095        0.248780   0.659270    0.206897          0.035714
# 411  0.380952        0.156836   0.376521    0.152639          0.250000
#
#      Education  EducationField  EnvironmentSatisfaction    Gender  HourlyRate  \
# ...

# %%
Test['Attrition'].value_counts()
# Out:
# 0    391
# 1     21
# Name: Attrition, dtype: int64

# %%
Train['Attrition'].value_counts()
# Out:
# 0    879
# 1    179
# Name: Attrition, dtype: int64

# %%
round(Test['Attrition'].value_counts(normalize=True)*100,2)
# Out:
# 0    94.9
# 1     5.1
# Name: Attrition, dtype: float64
